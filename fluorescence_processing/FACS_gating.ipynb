# %%
# %matplotlib widget
# %load_ext autoreload
# %autoreload 2

import numpy as np
from bsccm import BSCCM
import matplotlib.pyplot as plt

dataset = BSCCM('/home/henry/BSCCM_local/BSCCM/')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Mark cells that belong to a single fluorescent population

# %%
img_fig = plt.figure(figsize=(5,5))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
unstained = dataset.index_dataframe[
    np.logical_and(dataset.index_dataframe.antibodies == 'unstained',
                   dataset.index_dataframe.batch == 0)]

# %%
unstained
# Out:
#        global_index  position_in_fov_y_pix  position_in_fov_x_pix  \
# 52923         52923                   1318                    670
# 52924         52924                   1225                    419
# 52925         52925                   1136                   1733
# 52926         52926                    893                   1503
# 52927         52927                   1252                   1160
# ...             ...                    ...                    ...
# 69256         69256                   1609                    823
# 69257         69257                   1111                   1735
# 69258         69258                   1026                   1155
# 69259         69259                    655                   1219
# 69260         69260                    806                    333
#
#        detection_radius  has_matched_histology_cell  batch antibodies  \
# 52923             20.48                       False      0  unstained
# 52924             20.48                       False      0  unstained
# 52925             20.48                       False      0  unstained
# 52926             20.48                       False      0  unstained
# 52927             20.48                       False      0  unstained
# ...                 ...                         ...    ...        ...
# 69256             20.48                       False      0  unstained
# 69257             20.48                       False      0  unstained
# 69258             20.48                       False      0  unstained
# 69259             20.48                        True      0  unstained
# 69260             20.48                       False      0  unstained
#
#       imaging_date  fluor_shading_correction_index notes  \
# 52923   2018-08-19                               1   NaN
# 52924   2018-08-19                               1   NaN
# 52925   2018-08-19                               1   NaN
# 52926   2018-08-19                               1   NaN
# 52927   2018-08-19                               1   NaN
# ...            ...                             ...   ...
# 69256   2018-08-19                               1   NaN
# 69257   2018-08-19                               1   NaN
# 69258   2018-08-19                               1   NaN
# 69259   2018-08-19                               1   NaN
# 69260   2018-08-19                               1   NaN
#
#                                             data_path  slide_replicate
# 52923  antibodies_unstained/batch_0/slide_replicate_0                0
# 52924  antibodies_unstained/batch_0/slide_replicate_0                0
# 52925  antibodies_unstained/batch_0/slide_replicate_0                0
# 52926  antibodies_unstained/batch_0/slide_replicate_0                0
# 52927  antibodies_unstained/batch_0/slide_replicate_0                0
# ...                                               ...              ...
# 69256  antibodies_unstained/batch_0/slide_replicate_0                0
# 69257  antibodies_unstained/batch_0/slide_replicate_0                0
# 69258  antibodies_unstained/batch_0/slide_replicate_0                0
# 69259  antibodies_unstained/batch_0/slide_replicate_0                0
# 69260  antibodies_unstained/batch_0/slide_replicate_0                0
#
# [16338 rows x 12 columns]

# %%
from facs_util import ScatterSelectorGating



gating = ScatterSelectorGating(unstained.global_index.to_numpy(), data, channel_names, img_fig,

# %%
dataset.dataframe.columns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-edd0a980090a> in <module>
# ----> 1 dataset.dataframe.columns
#
# AttributeError: 'BSCCM' object has no attribute 'dataframe'

# %%
from facs_util import ScatterSelectorGating

# Which unmixing strategy should be used?

# prefix = 'unmixed_0+2_'
# prefix = 'unmixed_1+2_'
prefix = 'unmixed_6+2uniform_'
# prefix = 'unmixed_6+2noreg_'
# prefix = 'unmixed_6+2mean_autofluor_'
# prefix = 'unmixed_6+0uniform_'
# prefix = 'unmixed_6+0noreg_'

channel_names = ['CD123', 'CD3/CD19/CD56',
       'HLA-DR', 'CD45', 'CD14', 'CD16', 'autofluor_1', 'autofluor_2']
unmixed_channel_names = [prefix + ch for ch in channel_names]

indices = dataset.get_indices(marker='all', batch=1, replicate=1)
data = dataset.dataframe[unmixed_channel_names].to_numpy()
 #Add globals to class
ssg = ScatterSelectorGating(indices, data, channel_names, dataset, img_fig)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-b954a0c0657e> in <module>
#      15 unmixed_channel_names = [prefix + ch for ch in channel_names]
#      16
# ---> 17 indices = dataset.get_indices(marker='all', batch=1, replicate=1)
#      18 data = dataset.dataframe[unmixed_channel_names].to_numpy()
#      19  #Add globals to class
#
# TypeError: get_indices() got an unexpected keyword argument 'replicate'
